# %%
# importing Required modules
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# iomporting data set into our program
df = pd.read_csv('D:\youtubers_df.csv',encoding='unicode_escape')
df.shape
# Out:
# (1000, 9)

# %%
df.head(10)
# Out:
#    Rank            Username               Categories   Suscribers  \
# 0     1             tseries          MÃºsica y baile  249500000.0
# 1     2             MrBeast       Videojuegos, Humor  183500000.0
# 2     3           CoComelon               EducaciÃ³n  165500000.0
# 3     4            SETIndia                      NaN  162600000.0
# 4     5       KidsDianaShow     AnimaciÃ³n, Juguetes  113500000.0
# 5     6           PewDiePie  PelÃ­culas, Videojuegos  111500000.0
# 6     7  LikeNastyaofficial                 Juguetes  107500000.0
# 7     8         VladandNiki     AnimaciÃ³n, Juguetes  101400000.0
# 8     9     zeemusiccompany          MÃºsica y baile   99700000.0
# 9    10                 WWE              Videojuegos   97200000.0
#
#           Country       Visits      Likes  Comments  \
# 0           India      86200.0     2700.0      78.0
# 1  Estados Unidos  117400000.0  5300000.0   18500.0
# 2         Unknown    7000000.0    24700.0       0.0
# 3           India      15600.0      166.0       9.0
# 4         Unknown    3900000.0    12400.0       0.0
# 5  Estados Unidos    2400000.0   197300.0    4900.0
# 6         Unknown    2600000.0    28000.0       0.0
# 7         Unknown    4100000.0    22100.0       0.0
# 8           India      74300.0     2600.0      32.0
# 9  Estados Unidos     184500.0     6300.0     214.0
#
#                                                Links
# 0  http://youtube.com/channel/UCq-Fj5jknLsUf-MWSy...
# 1  http://youtube.com/channel/UCX6OQ3DkcsbYNE6H8u...
# 2  http://youtube.com/channel/UCbCmjCuTUZos6Inko4...
# 3  http://youtube.com/channel/UCpEhnqL0y41EpW2TvW...
# 4  http://youtube.com/channel/UCk8GzjMOrta8yxDcKf...
# 5  http://youtube.com/channel/UC-lHJZR3Gqxm24_Vd_...
# 6  http://youtube.com/channel/UCJplp5SjeGSdVdwsfb...
# 7  http://youtube.com/channel/UCvlE5gTbOvjiolFlEm...
# 8  http://youtube.com/channel/UCFFbwnve3yF62-tVXk...
# 9  http://youtube.com/channel/UCJ5v_MCY6GNUBTO8-D...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Rank        1000 non-null   int64
#  1   Username    1000 non-null   object
#  2   Categories  694 non-null    object
#  3   Suscribers  1000 non-null   float64
#  4   Country     1000 non-null   object
#  5   Visits      1000 non-null   float64
#  6   Likes       1000 non-null   float64
#  7   Comments    1000 non-null   float64
#  8   Links       1000 non-null   object
# dtypes: float64(4), int64(1), object(4)
# memory usage: 70.4+ KB

# %%
pd.isnull(df)
# Out:
#       Rank  Username  Categories  Suscribers  Country  Visits  Likes  \
# 0    False     False       False       False    False   False  False
# 1    False     False       False       False    False   False  False
# 2    False     False       False       False    False   False  False
# 3    False     False        True       False    False   False  False
# 4    False     False       False       False    False   False  False
# ..     ...       ...         ...         ...      ...     ...    ...
# 995  False     False        True       False    False   False  False
# 996  False     False        True       False    False   False  False
# 997  False     False       False       False    False   False  False
# 998  False     False        True       False    False   False  False
# 999  False     False       False       False    False   False  False
#
#      Comments  Links
# 0       False  False
# 1       False  False
# 2       False  False
# 3       False  False
# 4       False  False
# ..        ...    ...
# 995     False  False
# 996     False  False
# 997     False  False
# 998     False  False
# 999     False  False
#
# [1000 rows x 9 columns]

# %%
pd.isnull(df).sum()
# Out:
# Rank            0
# Username        0
# Categories    306
# Suscribers      0
# Country         0
# Visits          0
# Likes           0
# Comments        0
# Links           0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.columns
# Out:
# Index(['Rank', 'Username', 'Categories', 'Suscribers', 'Country', 'Visits',
#        'Likes', 'Comments', 'Links'],
#       dtype='object')

# %%
df.describe()
# Out:
#               Rank    Suscribers        Visits         Likes       Comments
# count   694.000000  6.940000e+02  6.940000e+02  6.940000e+02     694.000000
# mean    495.298271  2.241556e+07  1.210730e+06  5.347360e+04    1558.793948
# std     289.222212  1.824123e+07  6.038274e+06  2.979711e+05    7967.470234
# min       1.000000  1.170000e+07  0.000000e+00  0.000000e+00       0.000000
# 25%     244.250000  1.380000e+07  3.692500e+04  5.685000e+02       2.000000
# 50%     492.500000  1.680000e+07  1.587000e+05  3.550000e+03      78.000000
# 75%     746.750000  2.390000e+07  8.339000e+05  2.377500e+04     499.750000
# max    1000.000000  2.495000e+08  1.174000e+08  5.300000e+06  154000.000000

# %%
df[['Rank','Suscribers','Visits']].describe()
# Out:
#               Rank    Suscribers        Visits
# count   694.000000  6.940000e+02  6.940000e+02
# mean    495.298271  2.241556e+07  1.210730e+06
# std     289.222212  1.824123e+07  6.038274e+06
# min       1.000000  1.170000e+07  0.000000e+00
# 25%     244.250000  1.380000e+07  3.692500e+04
# 50%     492.500000  1.680000e+07  1.587000e+05
# 75%     746.750000  2.390000e+07  8.339000e+05
# max    1000.000000  2.495000e+08  1.174000e+08

# %%
# to Visualize the The details of the particular Channel
channel_name = input("Enter the channel name you want to visualize (case-sensitive): ")

# %%
if channel_name not in df['Username'].values:
    print(f"Channel '{channel_name}' not found in the dataset.")
else:
    # Select data for the specified channel
    channel_data = df[df['Username'] == channel_name]
    
    plt.figure(figsize=(10, 5))
      # Subscribers, Visits, Likes, Comments, and Links
    plt.subplot(1, 4, 1)
    plt.bar(['Suscribers'], channel_data['Suscribers'], color='skyblue')
    plt.title('Suscribers')

    plt.subplot(1, 4, 2)
    plt.bar(['Visits'], channel_data['Visits'], color='lightcoral')
    plt.title('Visits')

    plt.subplot(1, 4, 3)
    plt.bar(['Likes'], channel_data['Likes'], color='mediumseagreen')
    plt.title('Likes')

    plt.subplot(1, 4, 4)
    plt.bar(['Comments'], channel_data['Comments'], color='gold')
    plt.title('Comments')

    # Print descriptive information
    print(f"\nDescriptive Information for Channel: {channel_name}")
    print(f"Country: {channel_data['Country'].values[0]}")
    print(f"Categories: {channel_data['Categories'].values[0]}")
    print(f"Links: {channel_data['Links'].values[0]}\n")

    plt.suptitle(f'Detailed Metrics for Channel: {channel_name}')
    plt.tight_layout(rect=[0, 0, 1, 0.96])
    plt.show()
# Out:
# Descriptive Information for Channel: MrBeast
# Country: Estados Unidos
# Categories: Videojuegos, Humor
# Links: http://youtube.com/channel/UCX6OQ3DkcsbYNE6H8uQQuVA

# %%
# Representing The Top 10 Highest Liked Channels with links
top_10_videos = df.nlargest(10, 'Likes')
print("Top 10 Videos with the Highest Likes:")
for index, row in top_10_videos.iterrows():
    video_title = row['Username']
    video_likes = row['Likes']
    video_link = row['Links']
    print(f"\nTitle: {video_title}\nLikes: {video_likes}\nLink: {video_link}")
# Out:
# Top 10 Videos with the Highest Likes:
#
# Title: MrBeast
# Likes: 5300000.0
# Link: http://youtube.com/channel/UCX6OQ3DkcsbYNE6H8uQQuVA
#
# Title: MrBeast2
# Likes: 5000000.0
# Link: http://youtube.com/channel/UC4-79UOlP48-QNGgCko5p2g
#
# Title: DaFuqBoom
# Likes: 1700000.0
# Link: http://youtube.com/channel/UCsSsgPaZ2GSmO6il8Cb5iGA
#
# Title: triggeredinsaan
# Likes: 1400000.0
# Link: http://youtube.com/channel/UCfLuT3JwLx8rvHjHfTymekw
#
# Title: BeastPhilanthropy
# Likes: 952100.0
# Link: http://youtube.com/channel/UCAiLfjNXkNv24uhpzUgPa6A
#
# Title: alanbecker
# Likes: 582600.0
# Link: http://youtube.com/channel/UCbKWv2x9t6u8yZoB3KcPtnw
#
# Title: khangsresearchcentre1685
# Likes: 501700.0
# Link: http://youtube.com/channel/UCatL-c6pmnjzEOHSyjn-sHA
#
# Title: GoAmiGo
# Likes: 455300.0
# Link: http://youtube.com/channel/UCp4Fk7Xy_wYq8sFKcKNrQCA
#
# Title: Vsauce
# Likes: 449000.0
# Link: http://youtube.com/channel/UC6nSFpj9HTCZ5t-N3Rm3-HA
#
# Title: fedevigevani
# Likes: 412200.0
# Link: http://youtube.com/channel/UCoQm-PeHC-cbJclKJYJ8LzA

# %%
# Visualizibg Top10 most subscribed channels with there country names
plt.figure(figsize=(12, 6))
top_10_channels = df.sort_values(by='Suscribers', ascending=False).head(10)
bars = plt.bar(top_10_channels['Username'], top_10_channels['Suscribers'], color='skyblue')
plt.xlabel('Channel Names')
plt.ylabel('Subscribers Count')
plt.title('Top 10 Most Subscribed Channels')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability

# Displaying channel names and corresponding country names on top of the bars
for bar, username, country in zip(bars, top_10_channels['Username'], top_10_channels['Country']):
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval + 0.01 * max(top_10_channels['Suscribers']),
             f"{username}\n({country})", ha='center', va='bottom')

plt.tight_layout()
plt.show()

# %%
# visualizing countries with num of youtube channel
sns.set(rc={'figure.figsize':(30,6)})
ax=sns.countplot(x='Country',data=df)

# %%
df['Categories'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0              MÃºsica y baile
# 1           Videojuegos, Humor
# 2                   EducaciÃ³n
# 4         AnimaciÃ³n, Juguetes
# 5      PelÃ­culas, Videojuegos
#                 ...
# 989                      Humor
# 990                 PelÃ­culas
# 991                 EducaciÃ³n
# 997            MÃºsica y baile
# 999       Noticias y PolÃ­tica
# Name: Categories, Length: 694, dtype: object>

# %%
num_unique_Usernames = df['Username'].nunique()
print(f"Number of Unique Usernames: {num_unique_Usernames}")
# Out:
# Number of Unique Usernames: 689

# %%
# Taking the unique categories 
num_unique_categories = df['Categories'].nunique()
print(f"Number of Unique Categories: {num_unique_categories}")
# Out:
# Number of Unique Categories: 45

# %%
unique_categories = df['Categories'].unique()
print(unique_categories)
# Out:
# ['MÃºsica y baile' 'Videojuegos, Humor' 'EducaciÃ³n'
#  'AnimaciÃ³n, Juguetes' 'PelÃ\xadculas, Videojuegos' 'Juguetes'
#  'Videojuegos' 'PelÃ\xadculas, AnimaciÃ³n' 'PelÃ\xadculas'
#  'Noticias y PolÃ\xadtica' 'AnimaciÃ³n, Humor'
#  'MÃºsica y baile, AnimaciÃ³n' 'MÃºsica y baile, PelÃ\xadculas'
#  'PelÃ\xadculas, Juguetes' 'PelÃ\xadculas, Humor' 'Vlogs diarios'
#  'Videojuegos, Juguetes' 'AnimaciÃ³n, Videojuegos' 'AnimaciÃ³n'
#  'MÃºsica y baile, Humor' 'DiseÃ±o/arte, DIY y Life Hacks'
#  'Ciencia y tecnologÃ\xada' 'Fitness, Salud y autoayuda' 'Belleza, Moda'
#  'Humor' 'Comida y bebida' 'Deportes' 'Fitness' 'Viajes, EspectÃ¡culos'
#  'Comida y bebida, Salud y autoayuda' 'DiseÃ±o/arte'
#  'DIY y Life Hacks, Juguetes' 'EducaciÃ³n, Juguetes'
#  'Juguetes, Coches y vehÃ\xadculos' 'MÃºsica y baile, Juguetes'
#  'Animales y mascotas' 'ASMR' 'Moda' 'DIY y Life Hacks'
#  'DiseÃ±o/arte, Belleza' 'Coches y vehÃ\xadculos'
#  'AnimaciÃ³n, Humor, Juguetes' 'ASMR, Comida y bebida'
#  'Comida y bebida, Juguetes' 'Juguetes, DIY y Life Hacks']

# %%
category_counts = df['Categories'].value_counts()

# Increase the size of the graph
plt.figure(figsize=(20, 8))

# Plotting
category_counts.plot(kind='bar', color='skyblue')
plt.xlabel('Categories')
plt.ylabel('Number of Usernames')
plt.title('Number of Usernames for Each Unique Category')

# Displaying the count on top of each bar
for i, count in enumerate(category_counts):
    plt.text(i, count + 0.1, str(count), ha='center', va='bottom')

plt.xticks(rotation=45, ha='right')
plt.show()

# %% [markdown]
# Here we analyzed a diwali sales data to create insights and noticed that , out of the 689 channels that were provided for analysis in tat there are 45 Categories , Tseries an Indian channel has the highest subscriber count, Estados Unidos country has the highest channel count, and Mr. Bear's channel has the highest like counts.
